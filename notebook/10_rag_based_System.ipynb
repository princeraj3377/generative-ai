# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader("../data/speech.txt")

# %%
loader

# %%
text = loader.load()

# %%
onedoc= text[0]
print(onedoc.page_content)
# Out:
# “My dear friends, students, and respected farmers,
#
# Today, I want to speak from the heart about three pillars that define the future of our nation:
# our youth, our education system, and our farmers.
#
# 🎓 For the Youth
#
# You are the energy that drives our state forward.
# Our commitment is to give you:
# 	•	Skill-based education
# 	•	Digital learning opportunities
# 	•	Better employment pathways
# 	•	Support for innovation, startups, and entrepreneurship
#
# Your dreams are not just your own—they are the dreams of our entire society.
#
# 📚 For Education
#
# Education must not be just a formality; it must be a force of transformation.
# We aim to:
# 	•	Upgrade government schools with smart classrooms
# 	•	Improve teacher training
# 	•	Expand scholarships for higher education
# 	•	Promote technical and vocational courses
# 	•	Ensure every child gets a fair opportunity to learn and grow
#
# Education is the foundation on which we will build tomorrow.
#
# 👨‍🌾 For Farmers
#
# ...

# %% [markdown]
# ### pdf loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/medical_report.pdf")
doc2=loader.load()

# %%
onedoc1 = doc2[0]
print(onedoc1.page_content)
# Out:
# Report Status
# Female
# 27 Years:
# :
# :
# :
# Age
# Gender
# Reported
# P
# 9/7/2025   4:56:00PM
# DR NITIN NAHAR
# 474764803
# Ms. NIKITA  CHUDHARY:
# :
# :
# :
# :
# Name
# Lab No.
# Ref By
# Collected
# A/c Status
# 10/7/2025  6:31:50PM
# Final
# Collected at            : Processed at             :BHOPAL CC-82
# Mr Rachel V John Pata So Vitus John Mig 26
# Graund,Indrapuri, Phone: 8770817968
#
# LPL - Bhopal Lab II
# Plot No.05, Mandakini Housing Society, Near
# Apurti Shopping Mall, Kolar Main Road,
# Bhopal, M.P. -  462042
# Test Report
# Test Name Results Units Bio. Ref. Interval
# HEMOGRAM
# (SLS Method, Sheath Flow DC Detection Method, Fluorescent Flow Cytometry, Calculated & Capillary Photometry)
# Hemoglobin  12.00 - 15.00 g/dL13.10
# Packed Cell Volume (PCV)  36.00 - 46.00 %39.50
# RBC Count  3.80 - 4.80 mill/mm34.47
# MCV  83.00 - 101.00 fL88.40
# Mentzer Index   19.8
# MCH  27.00 - 32.00 pg29.30
# MCHC  31.50 - 34.50 g/dL33.20
# ...

# %%
for i, doc in enumerate(doc2):
    print(f"Page {i + 1}: {len(doc.page_content.strip())} characters")
# Out:
# Page 1: 1423 characters
# Page 2: 1331 characters
# Page 3: 1241 characters
# Page 4: 1361 characters
# Page 5: 2527 characters
# Page 6: 2920 characters
# Page 7: 1024 characters
# Page 8: 2936 characters
# Page 9: 3381 characters

# %% [markdown]
#  ### csv file loader

# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader= CSVLoader("../data/employee_records.csv")
deoc =loader.load()

# %%
for i, doc in enumerate(doc2[:6]):
    print(f"Document {i}:")
    print(doc.page_content)
    print("-" * 40)
# Out:
# Document 0:
# Report Status
# Female
# 27 Years:
# :
# :
# :
# Age
# Gender
# Reported
# P
# 9/7/2025   4:56:00PM
# DR NITIN NAHAR
# 474764803
# Ms. NIKITA  CHUDHARY:
# :
# :
# :
# :
# Name
# Lab No.
# Ref By
# Collected
# A/c Status
# 10/7/2025  6:31:50PM
# Final
# Collected at            : Processed at             :BHOPAL CC-82
# Mr Rachel V John Pata So Vitus John Mig 26
# Graund,Indrapuri, Phone: 8770817968
#
# LPL - Bhopal Lab II
# Plot No.05, Mandakini Housing Society, Near
# Apurti Shopping Mall, Kolar Main Road,
# Bhopal, M.P. -  462042
# Test Report
# Test Name Results Units Bio. Ref. Interval
# HEMOGRAM
# (SLS Method, Sheath Flow DC Detection Method, Fluorescent Flow Cytometry, Calculated & Capillary Photometry)
# Hemoglobin  12.00 - 15.00 g/dL13.10
# Packed Cell Volume (PCV)  36.00 - 46.00 %39.50
# RBC Count  3.80 - 4.80 mill/mm34.47
# MCV  83.00 - 101.00 fL88.40
# Mentzer Index   19.8
# MCH  27.00 - 32.00 pg29.30
# MCHC  31.50 - 34.50 g/dL33.20
# ...

# %% [markdown]
# ### web page loader

# %% [markdown]
# fro|

# %%
from langchain_community.document_loaders import WebBaseLoader
loader =WebBaseLoader(web_path="https://www.meesho.io/scams")
docss =loader.load()

# %%
docss[0].page_content
# Out:
# "Job Scams | Beware of job scams\n\nOpen sidebarCareersOpen main menuAbout UsTech at MeeshoLife @ MeeshoBlogsJob ScamsEarly CareersCareersBe sure that your job offer is genuine!Beware of Fake OffersIt has come to our notice that certain individuals and groups are misusing the name and logo of Meesho to deceive job seekers. These actors are creating fake websites, reaching out via phone calls or social media platforms (such as Telegram, WhatsApp, Instagram, etc.), and attempting to extract money or sensitive information from individuals under the pretext of offering jobs. In some cases, they are even issuing fake offer letters and asking candidates to pay for mandatory pre‑joining training or similar courses. Please note: Meesho does not charge any fees at any stage of the hiring process, nor do we require any paid training before joining. We want to ensure that no job seeker falls victim to such fraudulent practices. Here are some ways to identify genuine Meesho job opportunities and
# ...

# %% [markdown]
# ### use wikipedia

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="apple company", load_max_docs=2)
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'title': 'Apple Inc.', 'summary': 'Apple Inc. is an American multinational technology company headquartered in Cupertino, California, in Silicon Valley, and known for consumer electronics, software and online services. Founded in 1976 as Apple Computer Company by Steve Jobs, Steve Wozniak and Ronald Wayne, the company was incorporated by Jobs and Wozniak as Apple Computer, Inc. the following year. Its current name was adopted in 2007 as the company expanded its focus from computers to consumer electronics. Apple is one of the Big Tech companies.\nThe company was founded to market Wozniak\'s Apple I computer. Its successor, the Apple II, became one of the first successful mass-produced personal microcomputers. Apple introduced the Lisa in 1983 and the Macintosh in 1984, popularizing graphical user interfaces navigated by a mouse. By 1985, internal conflicts led to Jobs leaving the company to form NeXT and Wozniak stepping back from active employment. During the 199
# ...
