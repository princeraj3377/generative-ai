# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
from langchain_ollama import ChatOllama

# %%
llm= ChatOllama(model="gemma4:31b-cloud")

# %%
res= llm.invoke("what is gen ai?")
print(res.content)
# Out:
# **Generative AI** (or **GenAI**) is a type of Artificial Intelligence that can **create new content**.
#
# While traditional AI is designed to recognize patterns, follow rules, or make predictions based on existing data (called *Discriminative AI*), Generative AI goes a step further by using those patterns to generate entirely new data that looks or sounds like it was made by a human.
#
# Here is a detailed breakdown of how it works, what it does, and why it’s different.
#
# ---
#
# ### 1. How does it work? (The Simple Version)
# Imagine you show a computer 10 million pictures of cats.
# *   **Traditional AI** learns what a cat looks like so that if you show it a new photo, it can say, *"Yes, this is a cat."*
# *   **Generative AI** learns the "essence" of a cat (the pointed ears, the whiskers, the fur texture) so that if you ask it, it can draw a brand-new picture of a cat that has never existed before.
#
# It does this using **Foundation Models** (like Large Language Models or LLMs). These models are trained on massive amounts of data and learn the statistical probability of what comes next. For example, if a GenAI model sees the words *"The capital of France is..."*, it knows that statistically, the most likely next word is *"Paris."*
#
# ### 2. What can it create?
# Generative AI isn't just about chatbots; it works across many different mediums:
#
# *   **Text:** Writing emails, essays, poems, or computer code (e.g., **ChatGPT, Claude, Gemini**).
# *   **Images:** Creating photorealistic art, logos, or surreal landscapes from a text prompt (e.g., **Midjourney, DALL-E 3, Stable Diffusion**).
# *   **Audio:** Generating music, cloning voices, or turning text into speech (e.g., **Suno, ElevenLabs**).
# *   **Video:** Creating short movie clips or animations from text (e.g., **Sora, Runway**).
#
# ### 3. Generative AI vs. Traditional AI
#
# | Feature | Traditional (Discriminative) AI | Generative AI |
# | :--- | :--- | :--- |
# | **Goal** | Analyze, Classify, Predict | Create, Imagine, Synthesize |
# | **Output** | A label, a number, or a "Yes/No" | A paragraph, an image, a song |
# | **Example** | Netflix suggesting a movie you'll like | ChatGPT writing a script for a movie |
# | **Logic** | "Is this a picture of a dog?" | "Draw me a dog wearing a top hat." |
#
# ### 4. Why is it a big deal?
# GenAI is transformative because it lowers the barrier to creativity and productivity. It allows people who cannot code to build apps, people who cannot draw to create visuals, and businesses to automate complex writing tasks in seconds.
#
# ### 5. The "Catch" (Challenges)
# Despite its power, GenAI has some significant flaws:
# *   **Hallucinations:** Because it is predicting the "next likely word" rather than checking a database of facts, it can confidently state things that are completely false.
# *   **Copyright Issues:** Since these models are trained on human-made art and writing, there are ongoing legal battles about whether that is "fair use."
# *   **Bias:** If the training data contains human prejudices, the AI will likely repeat those biases in its output.

# %%
chatwithOllama = ChatOllama(model="gemma4:31b-cloud", streaming=True)

# %%
question = "What is generative AI?"
res = chatwithOllama.stream(question)
for chunk in res:
    print(chunk.content, end="", flush=True)
# Out:
# At its simplest level, **Generative AI (GenAI)** is a type of artificial intelligence that can create **new content**.
#
# While traditional AI is designed to recognize patterns, follow rules, or make predictions based on existing data (called *Discriminative AI*), Generative AI goes a step further by using those patterns to generate entirely new data that looks and feels like it was made by a human.
#
# Here is a detailed breakdown of how it works, what it can do, and why it is different.
#
# ---
#
# ### 1. How does it work? (The "Intuition")
# Generative AI doesn't "think" or "know" things the way humans do. Instead, it uses **Machine Learning**—specifically **Neural Networks**—to analyze massive amounts of existing data.
#
# Imagine an AI being shown 10 million pictures of cats. It doesn't just memorize the images; it learns the *mathematical patterns* of what makes a "cat" (e.g., pointed ears, whiskers, a certain eye shape). Once it understands these patterns, it can create a brand-new image of a cat that has never existed before by arranging pixels in a way that fits those learned patterns.
#
# ### 2. Common Types of Generative AI
# GenAI is categorized by the type of "output" it creates:
#
# *   **Text (LLMs):** Large Language Models like **ChatGPT (OpenAI), Claude (Anthropic), and Gemini (Google)**. They predict the next most likely word in a sequence to write essays, code, poems, or emails.
# *   **Images:** Tools like **Midjourney, DALL-E, and Stable Diffusion**. These turn text descriptions (prompts) into visual art or photorealistic images.
# *   **Audio/Speech:** AI that can create original music, clone a person's voice, or turn text into natural-sounding speech.
# *   **Video:** Emerging tools like **Sora or Runway** that can generate short video clips from a simple text prompt.
#
# ### 3. Generative AI vs. Traditional AI
# To understand the difference, imagine you have a database of a thousand songs:
#
# *   **Traditional AI (Discriminative):** You give it a song, and it tells you, *"This is a Jazz song."* (It **classifies**).
# *   **Generative AI:** You tell it, *"Write me a new Jazz song in the style of Miles Davis,"* and it creates a brand-new piece of music. (It **creates**).
#
# ### 4. The "Catch": Limitations and Risks
# Because Generative AI is based on probability and patterns rather than a factual understanding of the world, it has some significant flaws:
#
# *   **Hallucinations:** The AI may confidently state a "fact" that is completely made up because that sequence of words *sounded* plausible.
# *   **Bias:** If the AI was trained on data that contains human prejudices, the AI will mirror those biases in its output.
# *   **Copyright Issues:** Since these models are trained on billions of pieces of human-made art and writing, there are ongoing legal debates about whether this constitutes "theft" or "fair use."
#
# ### Summary Table
# | Feature | Traditional AI | Generative AI |
# | :--- | :--- | :--- |
# | **Goal** | Analyze, Predict, Classify | Create, Imagine, Synthesize |
# | **Output** | A number, a label, a "Yes/No" | A paragraph, an image, a song |
# | **Example** | Netflix movie recommendations | Writing a screenplay for a movie |
# | **Analogy** | The Critic (judging the art) | The Artist (making the art) |

# %%
res
