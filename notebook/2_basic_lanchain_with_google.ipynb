# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=0.9
)

response = llm.invoke("Generative AI kya hai?")
print(response.model_dump())
# Out:
# /Users/hiten/Desktop/generative ai/env/lib/python3.14/site-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %% [markdown]
# ## CONNECT WITH GOOGLE GEMNI MODEL

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm2 = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=0.9
)

# %%
try:
    res = llm2.invoke("What is the capital of France?")
    print(res.content)
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# /Users/hiten/Desktop/generative ai/env/lib/python3.14/site-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': '...'}}]

# %%
prompts =[
    ("system","you are a pyhton developer"),
    ("user","write a python function to add two numbers"),  
]
res= llm2.invoke(prompts)
res.content
# Out:
# /Users/hiten/Desktop/generative ai/env/lib/python3.14/site-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text',
# ...

# %%
print(res.content)
# Out:
# [{'type': 'text', 'text': 'Here is a clean, well-documented Python function to add two numbers, including type hints and usage examples:\n\n```python\nfrom typing import Union\n\n\ndef add_numbers(\n    a: Union[int, float], b: Union[int, float]\n) -> Union[int, float]:\n    """Adds two numbers together and returns the sum.\n\n    Parameters:\n    a (int or float): The first number.\n    b (int or float): The second number.\n\n    Returns:\n    int or float: The sum of a and b.\n    """\n    return a + b\n\n\n# --- Example Usage ---\n\n# Adding two integers\nresult1 = add_numbers(5, 10)\nprint(f"5 + 10 = {result1}")  # Output: 15\n\n# Adding two floats\nresult2 = add_numbers(3.5, 2.5)\nprint(f"3.5 + 2.5 = {result2}")  # Output: 6.0\n\n# Adding a negative number\nresult3 = add_numbers(-4, 9)\nprint(f"-4 + 9 = {result3}")  # Output: 5\n```\n\n### Alternatively (One-liner):\nIf you just need a quick, simple function:\n\n```python\ndef add(a, b):\n    return a + b\n```', 'extras': {'sign
# ...
