# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text ="Today, I want to speak from the heart about three pillars that define the future of our nation:"\
    "our youth, our education system, and our farmers."

# %%
spiter=RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=20)

# %%
chunks = spiter.split_text(text)

# %%
chunks
# Out:
# ['Today, I want to speak from the heart about three',
#  'heart about three pillars that define the future',
#  'define the future of our nation:our youth, our',
#  'youth, our education system, and our farmers.']

# %% [markdown]
# ## document text spilltwre

# %%
from langchain_community.document_loaders import PyPDFLoader,TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = TextLoader("../data/speech.txt")
text= loader.load()

# %%
pdfloader = PyPDFLoader("../data/medical_report.pdf")
pdf = pdfloader.load()

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 100, chunk_overlap= 20)
text_chunk = splitter.split_documents(text)

# %%
text_chunk
# Out:
# [Document(metadata={'source': '../data/speech.txt'}, page_content='“My dear friends, students, and respected farmers,'),
#  Document(metadata={'source': '../data/speech.txt'}, page_content='Today, I want to speak from the heart about three pillars that define the future of our nation:'),
#  Document(metadata={'source': '../data/speech.txt'}, page_content='our youth, our education system, and our farmers.'),
#  Document(metadata={'source': '../data/speech.txt'}, page_content='🎓 For the Youth'),
#  Document(metadata={'source': '../data/speech.txt'}, page_content='You are the energy that drives our state forward.\nOur commitment is to give you:'),
#  Document(metadata={'source': '../data/speech.txt'}, page_content='•\tSkill-based education\n\t•\tDigital learning opportunities\n\t•\tBetter employment pathways'),
#  Document(metadata={'source': '../data/speech.txt'}, page_content='•\tSupport for innovation, startups, and entrepreneurship'),
# ...

# %% [markdown]
# pdf chunsk

# %%
pdfchunk = RecursiveCharacterTextSplitter(chunk_size =100, chunk_overlap = 10)
ttt = pdfchunk.split_documents(pdf)

# %%
ttt[0].page_content
# Out:
# 'Report Status    \nFemale\n27 Years:\n:\n:\n:\nAge\nGender\nReported        \nP\n9/7/2025   4:56:00PM'
